# %% [markdown]
# # Cell 1: Title and Introduction
# """
# # Algebra Examples with MathViz
#
# This notebook demonstrates various algebraic visualization techniques.
# """

# %%
# Cell 2: Import libraries
import mathviz
from mathviz import AlgebraVisualizer
import numpy as np
import matplotlib.pyplot as plt

# %%
viz = AlgebraVisualizer()
viz.quadratic_explorer()
plt.show()

# %%
# Cell 4: Polynomial comparison
viz.polynomial_explorer(degree=3)
plt.show()
