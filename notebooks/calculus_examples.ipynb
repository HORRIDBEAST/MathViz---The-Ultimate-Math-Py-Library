# %%
# Cell 2: Imports
from mathviz import CalculusVisualizer
import numpy as np
import matplotlib.pyplot as plt

# %%
calc_viz = CalculusVisualizer()
calc_viz.derivative_visualizer("x**3 - 3*x**2 + 2*x")
plt.show()

# %% [markdown]
# """
# # Calculus Visualizations with MathViz
#
# Exploring derivatives, integrals, and calculus concepts.
# """
